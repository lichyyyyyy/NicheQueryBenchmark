# %% [markdown]
# # Explore the Hongkui's Dataset
#
# Dataset: https://alleninstitute.github.io/abc_atlas_access/descriptions/WMB_dataset.html
#
# Manuscript: https://www.biorxiv.org/content/10.1101/2023.03.06.531121v1

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent.parent / "src"))

# %%
import pandas as pd

cells = pd.read_csv("data/hongkui-zeng/cell_metadata.csv")
cells
# Out:
#                     cell_label brain_section_label  cluster_alias  \
# 0        1019171907102340387-1   C57BL6J-638850.37           1408
# 1        1104095349101460194-1   C57BL6J-638850.26           4218
# 2          1017092617101450577   C57BL6J-638850.25           4218
# 3          1018093344101130233   C57BL6J-638850.13           4218
# 4          1019171912201610094   C57BL6J-638850.27           4218
# ...                        ...                 ...            ...
# 3938803  1018093344100380167-3   C57BL6J-638850.47           5252
# 3938804    1017165415100930567   C57BL6J-638850.57           5254
# 3938805    1017155956102610748   C57BL6J-638850.49           5254
# 3938806  1017155956101980080-1   C57BL6J-638850.50           5252
# 3938807  1018093344102220578-3   C57BL6J-638850.36           5252
#
#          average_correlation_score feature_matrix_label     donor_label  \
# 0                         0.596276       C57BL6J-638850  C57BL6J-638850
# 1                         0.641180       C57BL6J-638850  C57BL6J-638850
# 2                         0.763531       C57BL6J-638850  C57BL6J-638850
# 3                         0.558073       C57BL6J-638850  C57BL6J-638850
# 4                         0.591009       C57BL6J-638850  C57BL6J-638850
# ...                            ...                  ...             ...
# 3938803                   0.574988       C57BL6J-638850  C57BL6J-638850
# 3938804                   0.620546       C57BL6J-638850  C57BL6J-638850
# 3938805                   0.548053       C57BL6J-638850  C57BL6J-638850
# 3938806                   0.621901       C57BL6J-638850  C57BL6J-638850
# 3938807                   0.625139       C57BL6J-638850  C57BL6J-638850
#
#         donor_genotype donor_sex         x         y     z  \
# 0                wt/wt         M  7.226245  4.148963   6.6
# 1                wt/wt         M  5.064889  7.309543   4.2
# 2                wt/wt         M  5.792921  8.189973   4.0
# 3                wt/wt         M  3.195950  5.868655   2.4
# 4                wt/wt         M  5.635732  7.995842   4.4
# ...                ...       ...       ...       ...   ...
# 3938803          wt/wt         M  1.560003  4.669243   8.8
# 3938804          wt/wt         M  5.032556  3.695696  11.0
# 3938805          wt/wt         M  2.549142  4.231188   9.2
# 3938806          wt/wt         M  1.381324  5.784595   9.4
# 3938807          wt/wt         M  6.184499  6.654317   6.4
#
#                                 abc_sample_id
# 0        c9881423-76a7-4835-ba8b-7942fd384b6b
# 1        aa815488-6487-4e47-8a5e-d82ac9933bc6
# 2        91ef7a85-8e3e-4410-8ee2-785788df3ebe
# 3        18991e17-fbd3-4ba0-9c60-1281f56ac520
# 4        5e155936-e40d-4c6b-8971-e7fb0079274b
# ...                                       ...
# 3938803  73bc8aed-8a4a-428d-8d75-c37d41766370
# 3938804  a137c81a-b2b8-4c85-b967-3ec5753e6833
# 3938805  4322a30f-c4c4-4f7a-a915-40037c62eaa6
# 3938806  b2c01bcb-5f98-4247-bb74-1ca4667220b5
# 3938807  be0a63d6-7927-414c-a486-ebbf1e722b0b
#
# [3938808 rows x 12 columns]

# %%
import pandas as pd

ccf = pd.read_csv("data/hongkui-zeng/ccf_coordinates.csv")
ccf
# Out:
# /var/folders/cb/yd_h3b5576d6wq5rydwp3_kr0000gn/T/ipykernel_34217/3313415675.py:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   ccf = pd.read_csv('data/hongkui-zeng/ccf_coordinates.csv')
#                     cell_label          x         y         z  \
# 0          1019171911101460569  12.282330  6.987808  7.385773
# 1          1019171911101550321  12.192214  7.002155  4.366855
# 2          1019171911100841066  12.500341  4.750392  7.074634
# 3          1019171911101400425  12.231647  6.544816  4.128568
# 4          1019171911101380264  12.238502  6.135836  2.948194
# ...                        ...        ...       ...       ...
# 3739956    1017201423100590639   0.244132  5.446741  5.165418
# 3739957    1017201423100550444   0.446877  3.450430  5.167952
# 3739958  1017201423100460203-1   0.478625  3.244104  5.535724
# 3739959  1017201423100380114-1   0.429646  3.922535  6.213221
# 3739960    1017201423100540125   0.496993  2.933842  5.088633
#
#          parcellation_index
# 0                       945
# 1                       945
# 2                       893
# 3                       842
# 4                         0
# ...                     ...
# 3739956                1005
# 3739957                 213
# 3739958                 497
# 3739959                 213
# 3739960                 688
#
# [3739961 rows x 5 columns]

# %%
# how many slices does dataset contain? How many cells per sample?
# `abc_sample_id`: an individual sample (animal / batch / experiment)
# `brain_section_label`: a brain slice of one sample

print("How many slices does `dataset` contain? How many cells per slice?\n")
print(
    cells["brain_section_label"]
    .value_counts()
    .describe(percentiles=[0.01, 0.05, 0.1, 0.25, 0.5, 0.75, 0.9, 0.95, 0.99])
)
# Out:
# How many slices does `dataset` contain? How many cells per slice?
#
# count        59.000000
# mean      66759.457627
# std       27961.023436
# min       13963.000000
# 1%        17487.660000
# 5%        23277.400000
# 10%       28637.000000
# 25%       44518.500000
# 50%       71231.000000
# 75%       90598.000000
# 90%       99887.600000
# 95%      106090.400000
# 99%      117629.940000
# max      120186.000000
# Name: count, dtype: float64

# %%
# how many brain sections does dataset contain?


print(
    "How many brain sections does `dataset` contain? How many cells per brain section?\n"
)
print(
    ccf["parcellation_index"]
    .value_counts()
    .describe(percentiles=[0.01, 0.05, 0.1, 0.25, 0.5, 0.75, 0.9, 0.95, 0.99])
)
# Out:
# How many brain sections does `dataset` contain? How many cells per brain section?
#
# count       677.000000
# mean       5524.314623
# std       12252.195961
# min           6.000000
# 1%           25.000000
# 5%          114.000000
# 10%         202.200000
# 25%         615.000000
# 50%        2027.000000
# 75%        6003.000000
# 90%       13653.400000
# 95%       20246.000000
# 99%       42865.600000
# max      234096.000000
# Name: count, dtype: float64

# %%
# given a brain section, how many samples include the section and how many cells are in this section per sample?
import pandas as pd

ccf_cell = pd.merge(cells, ccf, how="left", on="cell_label")
ccf_cell.groupby("parcellation_index")

print("Given a brain section, how many slices include the section?\n")
print(
    ccf_cell.groupby("parcellation_index")["brain_section_label"]
    .nunique()
    .describe(percentiles=[0.01, 0.05, 0.1, 0.25, 0.5, 0.75, 0.9, 0.95, 0.99])
)
# Out:
# Given a brain section, how many slices include the section?
#
# count    677.000000
# mean       7.308715
# std        5.166242
# min        1.000000
# 1%         1.000000
# 5%         2.000000
# 10%        2.000000
# 25%        4.000000
# 50%        6.000000
# 75%       10.000000
# 90%       14.000000
# 95%       16.200000
# 99%       23.240000
# max       50.000000
# Name: brain_section_label, dtype: float64

# %%
from NicheQueryPrototype.database import Database

parcellation_tree = Database().parse_parcellation_structure(
    json_path="data/parcellation/structure.json"
)
ccf_cell["parcellation_level"] = ccf_cell["parcellation_index"].map(
    lambda k: parcellation_tree.get(k, {}).get("st_level", -1)
)

s = ccf_cell.groupby(["parcellation_level", "parcellation_index"])[
    "brain_section_label"
].nunique()

print(
    "Given a brain section, how many slices include the section group by brain section level?\n"
)
print(
    s.groupby(level=0).describe(
        percentiles=[0.01, 0.05, 0.1, 0.25, 0.5, 0.75, 0.9, 0.95, 0.99]
    )
)
# Out:
# Given a brain section, how many slices include the section group by brain section level?
#
#                     count       mean        std   min     1%     5%   10%  \
# parcellation_level
# -1                   87.0   5.965517   6.182211   1.0   1.00   1.30   2.0
#  0                    1.0  10.000000        NaN  10.0  10.00  10.00  10.0
#  1                    4.0   9.750000   5.500000   5.0   5.03   5.15   5.3
#  2                    4.0   9.000000   3.366502   4.0   4.18   4.90   5.8
#  3                    2.0  17.500000  23.334524   1.0   1.33   2.65   4.3
#  5                    6.0   4.666667   2.338090   2.0   2.10   2.50   3.0
#  6                   21.0   9.142857   8.410028   1.0   1.00   1.00   2.0
#  7                   18.0   7.944444   5.207147   2.0   2.17   2.85   3.0
#  8                  182.0   7.439560   4.994381   1.0   1.00   2.00   2.0
#  9                  126.0   7.349206   4.295705   1.0   1.00   2.00   2.0
#  10                  34.0   7.617647   6.045357   1.0   1.00   1.00   2.0
#  11                 192.0   7.328125   4.354890   1.0   1.00   2.00   2.0
#
#                       25%   50%    75%   90%    95%    99%   max
# parcellation_level
# -1                   3.00   5.0   7.00   9.0  14.00  30.22  50.0
#  0                  10.00  10.0  10.00  10.0  10.00  10.00  10.0
#  1                   5.75   8.5  12.50  15.2  16.10  16.82  17.0
#  2                   8.50  10.5  11.00  11.0  11.00  11.00  11.0
#  3                   9.25  17.5  25.75  30.7  32.35  33.67  34.0
#  5                   4.00   4.0   4.75   7.0   8.00   8.80   9.0
#  6                   4.00   7.0  10.00  14.0  18.00  35.60  40.0
#  7                   3.00   7.0  11.00  15.3  16.30  17.66  18.0
#  8                   4.00   6.0  10.00  14.0  17.95  23.19  24.0
#  9                   4.00   7.0  10.00  13.5  15.50  17.75  19.0
#  10                  3.00   5.0  10.00  15.0  18.35  24.36  27.0
#  11                  4.00   7.0  10.00  13.0  16.00  18.09  21.0

# %%
s = ccf_cell.groupby(["parcellation_level"])["parcellation_index"].nunique()

print("# parcellations group by levels\n")
print(s)
# Out:
# # parcellations group by levels
#
# parcellation_level
# -1      87
#  0       1
#  1       4
#  2       4
#  3       2
#  5       6
#  6      21
#  7      18
#  8     182
#  9     126
#  10     34
#  11    192
# Name: parcellation_index, dtype: int64

# %%
s = ccf_cell.groupby(["parcellation_level", "parcellation_index"])[
    "cell_label"
].nunique()

print(
    "Given a brain section, how many cells in the brain section per brian slice group by brain section level?\n"
)
print(
    s.groupby(level=0).describe(
        percentiles=[0.01, 0.05, 0.1, 0.25, 0.5, 0.75, 0.9, 0.95, 0.99]
    )
)
# Out:
# Given a brain section, how many cells in the brain section per brian slice group by brain section level?
#
#                     count          mean           std      min        1%  \
# parcellation_level
# -1                   87.0   3085.091954   8432.979053     12.0     17.16
#  0                    1.0  49230.000000           NaN  49230.0  49230.00
#  1                    4.0   7204.000000   4413.332679   1169.0   1367.48
#  2                    4.0   2326.750000   1795.973529    940.0    955.72
#  3                    2.0  14149.500000  19515.440054    350.0    625.99
#  5                    6.0   2252.166667   2587.853274    186.0    189.95
#  6                   21.0   8117.857143  11407.504005     58.0     75.40
#  7                   18.0   8041.833333  11068.916522     69.0    172.70
#  8                  182.0   4319.467033   6810.420201      7.0     19.24
#  9                  126.0   5863.460317   8692.496413     54.0     90.00
#  10                  34.0   3391.705882   3848.329575     35.0     76.58
#  11                 192.0   5858.145833  16934.098213      6.0     10.64
#
#                           5%      10%       25%      50%       75%      90%  \
# parcellation_level
# -1                     81.70    125.8    289.00    793.0   1951.00   4405.4
#  0                  49230.00  49230.0  49230.00  49230.0  49230.00  49230.0
#  1                   2161.40   3153.8   6131.00   7936.0   9009.00  10668.6
#  2                   1018.60   1097.2   1333.00   1709.5   2703.25   4050.1
#  3                   1729.95   3109.9   7249.75  14149.5  21049.25  25189.1
#  5                    205.75    225.5    368.75    977.0   4385.75   5554.0
#  6                    145.00    362.0    806.00   2572.0  10657.00  17899.0
#  7                    587.50    767.9   1393.25   3141.5   9571.00  25222.8
#  8                     64.85    170.4    629.75   2024.5   5611.00  10145.9
#  9                    184.25    302.5    925.00   2670.0   6500.25  16008.5
#  10                   166.20    194.9    642.00   2018.5   4832.75   8796.1
#  11                    97.35    198.2    618.25   2311.5   5769.50  14726.5
#
#                          95%       99%       max
# parcellation_level
# -1                  15166.20  33735.96   64794.0
#  0                  49230.00  49230.00   49230.0
#  1                  11221.80  11664.36   11775.0
#  2                   4499.05   4858.21    4948.0
#  3                  26569.05  27673.01   27949.0
#  5                   5619.50   5671.90    5685.0
#  6                  22318.00  42452.40   47486.0
#  7                  34390.35  34709.27   34789.0
#  8                  15315.50  23113.83   69977.0
#  9                  26296.75  33315.25   53180.0
#  10                 10252.05  14788.10   16349.0
#  11                 17090.60  32688.78  223467.0

# %% [markdown]
# ## Choose a parcellation for spot check

# %%
ccf_cell
# Out:
#                     cell_label brain_section_label  cluster_alias  \
# 0        1019171907102340387-1   C57BL6J-638850.37           1408
# 1        1104095349101460194-1   C57BL6J-638850.26           4218
# 2          1017092617101450577   C57BL6J-638850.25           4218
# 3          1018093344101130233   C57BL6J-638850.13           4218
# 4          1019171912201610094   C57BL6J-638850.27           4218
# ...                        ...                 ...            ...
# 3938803  1018093344100380167-3   C57BL6J-638850.47           5252
# 3938804    1017165415100930567   C57BL6J-638850.57           5254
# 3938805    1017155956102610748   C57BL6J-638850.49           5254
# 3938806  1017155956101980080-1   C57BL6J-638850.50           5252
# 3938807  1018093344102220578-3   C57BL6J-638850.36           5252
#
#          average_correlation_score feature_matrix_label     donor_label  \
# 0                         0.596276       C57BL6J-638850  C57BL6J-638850
# 1                         0.641180       C57BL6J-638850  C57BL6J-638850
# 2                         0.763531       C57BL6J-638850  C57BL6J-638850
# 3                         0.558073       C57BL6J-638850  C57BL6J-638850
# 4                         0.591009       C57BL6J-638850  C57BL6J-638850
# ...                            ...                  ...             ...
# 3938803                   0.574988       C57BL6J-638850  C57BL6J-638850
# 3938804                   0.620546       C57BL6J-638850  C57BL6J-638850
# 3938805                   0.548053       C57BL6J-638850  C57BL6J-638850
# 3938806                   0.621901       C57BL6J-638850  C57BL6J-638850
# 3938807                   0.625139       C57BL6J-638850  C57BL6J-638850
#
#         donor_genotype donor_sex       x_x       y_x   z_x  \
# 0                wt/wt         M  7.226245  4.148963   6.6
# 1                wt/wt         M  5.064889  7.309543   4.2
# 2                wt/wt         M  5.792921  8.189973   4.0
# 3                wt/wt         M  3.195950  5.868655   2.4
# 4                wt/wt         M  5.635732  7.995842   4.4
# ...                ...       ...       ...       ...   ...
# 3938803          wt/wt         M  1.560003  4.669243   8.8
# 3938804          wt/wt         M  5.032556  3.695696  11.0
# 3938805          wt/wt         M  2.549142  4.231188   9.2
# 3938806          wt/wt         M  1.381324  5.784595   9.4
# 3938807          wt/wt         M  6.184499  6.654317   6.4
#
#                                 abc_sample_id        x_y       y_y       z_y  \
# 0        c9881423-76a7-4835-ba8b-7942fd384b6b   7.495417  2.445872  7.455066
# 1        aa815488-6487-4e47-8a5e-d82ac9933bc6   9.227966  6.133693  5.225024
# 2        91ef7a85-8e3e-4410-8ee2-785788df3ebe   9.344912  6.989939  6.002664
# 3        18991e17-fbd3-4ba0-9c60-1281f56ac520  10.977068  4.398568  3.305223
# 4        5e155936-e40d-4c6b-8971-e7fb0079274b   8.997138  6.798329  5.827197
# ...                                       ...        ...       ...       ...
# 3938803  73bc8aed-8a4a-428d-8d75-c37d41766370   5.321669  2.575568  1.694437
# 3938804  a137c81a-b2b8-4c85-b967-3ec5753e6833   3.493405  2.016746  5.317544
# 3938805  4322a30f-c4c4-4f7a-a915-40037c62eaa6   4.994629  2.542668  2.773582
# 3938806  b2c01bcb-5f98-4247-bb74-1ca4667220b5   4.611080  4.157295  1.459526
# 3938807  be0a63d6-7927-414c-a486-ebbf1e722b0b   7.343453  5.416893  6.386752
#
#          parcellation_index  parcellation_level
# 0                    1160.0                  -1
# 1                     564.0                   9
# 2                     761.0                   9
# 3                     718.0                   9
# 4                     761.0                   9
# ...                     ...                 ...
# 3938803               828.0                   9
# 3938804              1004.0                   8
# 3938805              1091.0                   8
# 3938806               863.0                   8
# 3938807              1086.0                  11
#
# [3938808 rows x 17 columns]

# %%
ccf_cell.donor_label.nunique()
# Out:
# 1

# %%
# random select a parcellation & sample

# step 1: print parcellation at a specific level # 987
target_parcellations = ccf_cell[ccf_cell["parcellation_level"] == 6][
    "parcellation_index"
].unique()
print(f"Check parcellation at level 6: {target_parcellations}")
# Out:
# Check parcellation at level 6: [ 987.  141.  485.  467.  500.  348. 1080.  278.  856.  826.  645.  669.
#   809. 1073.  157.  541.  818.  323.  822.  864.  339.]

# %%
# random select a parcellation & sample

# step 1: print parcellation at a specific level
target_parcellations = ccf_cell[ccf_cell["parcellation_level"] == 5][
    "parcellation_index"
].unique()
print(f"Check parcellation at level 5: {target_parcellations}")
# Out:
# Check parcellation at level 5: [1097.  771.  528.  549.  354.  315.]

# %%
# step 2: check # samples with this parcellation
target_parcellation = 207

with pd.option_context(
    "display.max_rows",
    None,
    "display.max_columns",
    None,
    "display.width",
    None,
    "display.max_colwidth",
    None,
):
    s = ccf_cell[ccf_cell["parcellation_index"] == target_parcellation][
        "brain_section_label"
    ].value_counts()
    print(
        f"Samples with this parcellation & # cells in this parcellation per sample: \n{s}"
    )
    print(
        f"Total samples: {s.shape[0]} out of {ccf_cell['brain_section_label'].nunique()}"
    )
# Out:
# Samples with this parcellation & # cells in this parcellation per sample:
# brain_section_label
# C57BL6J-638850.30    1387
# C57BL6J-638850.29     958
# C57BL6J-638850.31     688
# C57BL6J-638850.28     551
# Name: count, dtype: int64
# Total samples: 4 out of 59

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import BoundaryNorm, ListedColormap


def visualize_parcellation_subtree_on_section(
    df,
    parcellation_tree,
    brain_section_label,
    parcellation_index,
    *,
    x_col="x_x",
    y_col="y_x",
    section_col="brain_section_label",
    parc_col="parcellation_index",
    figsize=(9, 9),
    show=True,
):
    """Plot one brain section using cell_metadata x/y (default ``x_x`` / ``y_x`` after merge).

    Cells outside the target subtree are light gray. Descendant ``parcellation_index`` values are
    colored by **category** (IDs are arbitrary, not a continuous scale).

    Returns ``(fig, ax)``.
    """

    def _cell_in_subtree(pid, root_id, tree):
        if pd.isna(pid):
            return False
        info = tree.get(int(pid), {})
        return root_id in (info.get("parent_ids") or set())

    root_id = int(parcellation_index)
    sec = df[df[section_col] == brain_section_label]
    if sec.empty:
        raise ValueError(f"No cells for brain_section_label={brain_section_label!r}")

    sub_mask = sec[parc_col].map(
        lambda p: _cell_in_subtree(p, root_id, parcellation_tree)
    )
    hl = sec.loc[sub_mask].copy()

    region_name = parcellation_tree.get(root_id, {}).get("name", "?")
    fig, ax = plt.subplots(figsize=figsize)

    other = sec.loc[~sub_mask]
    if not other.empty:
        ax.scatter(
            other[x_col],
            other[y_col],
            s=0.45,
            c="#a8a8a8",
            alpha=0.75,
            linewidths=0,
            rasterized=True,
            label="outside target subtree",
        )

    if hl.empty:
        ax.set_title(
            f"{brain_section_label}\nNo cells under CCF id {root_id} ({region_name})"
        )
        if not other.empty:
            ax.legend(loc="upper right", framealpha=0.9)
    else:
        hl["pid"] = hl[parc_col].astype(int)
        uniq = np.sort(hl["pid"].unique())
        n = len(uniq)
        pid_to_code = {p: i for i, p in enumerate(uniq)}
        codes = hl["pid"].map(pid_to_code).to_numpy(dtype=float)

        tab20 = plt.cm.tab20(np.linspace(0, 1, 20, endpoint=False))
        tab20b = plt.cm.tab20b(np.linspace(0, 1, 20, endpoint=False))
        set3 = plt.cm.Set3(np.linspace(0, 1, 12, endpoint=False))
        pal = np.vstack([tab20, tab20b, set3])
        colors = [pal[i % len(pal)] for i in range(n)]
        cmap = ListedColormap(colors)
        bounds = np.arange(n + 1) - 0.5
        norm = BoundaryNorm(bounds, cmap.N)

        sc = ax.scatter(
            hl[x_col],
            hl[y_col],
            c=codes,
            cmap=cmap,
            norm=norm,
            s=1.2,
            alpha=0.9,
            linewidths=0,
        )
        cbar = plt.colorbar(sc, ax=ax, fraction=0.035, pad=0.02, ticks=np.arange(n))
        cbar.ax.set_yticklabels([str(u) for u in uniq])
        cbar.set_label("parcellation_index (categorical)")

        if not other.empty:
            ax.legend(loc="upper right", framealpha=0.9)

        ax.set_title(
            f"{brain_section_label}\nCCF {root_id} — {region_name}\n"
            f"{len(hl):,} cells in this structure or its descendants"
        )

    ax.set_xlabel("x (cell_metadata)")
    ax.set_ylabel("y (cell_metadata)")
    ax.set_aspect("equal", adjustable="box")
    fig.tight_layout()
    if show:
        plt.show()
    return fig, ax


target_sample_ids = [
    "C57BL6J-638850.30",
    "C57BL6J-638850.29",
    "C57BL6J-638850.31",
    "C57BL6J-638850.28",
]
for sample_id in target_sample_ids:
    visualize_parcellation_subtree_on_section(
        ccf_cell,
        parcellation_tree,
        brain_section_label=sample_id,
        parcellation_index=target_parcellation,
    )
