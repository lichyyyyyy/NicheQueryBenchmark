# %% [markdown]
# # Explore the Zhuang-ABCA Dataset
#
# Dataset: https://alleninstitute.github.io/abc_atlas_access/descriptions/zhuang-abca-4.html
#
# Manuscript: https://www.nature.com/articles/s41586-023-06808-9

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent.parent / "src"))

# %%
import pandas as pd

cells_abca_4 = pd.read_csv('data/zhuang-abca-4/cell_metadata.csv')
cells_abca_4
# Out:
#                                      cell_label brain_section_label  \
# 0       177536119734259275144748435471942472531   Zhuang-ABCA-4.002
# 1       256532006537596385088807329967308781746   Zhuang-ABCA-4.002
# 2        28801318882950773770397006451868070066   Zhuang-ABCA-4.002
# 3       301971869963235435117242882149875853185   Zhuang-ABCA-4.002
# 4        81203938259029510162263594992098070595   Zhuang-ABCA-4.002
# ...                                         ...                 ...
# 162573  207078638049612663505414491993744973724   Zhuang-ABCA-4.001
# 162574  269688622729976403473132483008812650057   Zhuang-ABCA-4.001
# 162575   32317399564312907213846667957826182632   Zhuang-ABCA-4.001
# 162576   54832320688289368628112079037767349797   Zhuang-ABCA-4.001
# 162577  329803029697740405562675653447986491968   Zhuang-ABCA-4.001
#
#        feature_matrix_label    donor_label donor_genotype donor_sex  \
# 0             Zhuang-ABCA-4  Zhuang-ABCA-4          wt/wt         M
# 1             Zhuang-ABCA-4  Zhuang-ABCA-4          wt/wt         M
# 2             Zhuang-ABCA-4  Zhuang-ABCA-4          wt/wt         M
# 3             Zhuang-ABCA-4  Zhuang-ABCA-4          wt/wt         M
# 4             Zhuang-ABCA-4  Zhuang-ABCA-4          wt/wt         M
# ...                     ...            ...            ...       ...
# 162573        Zhuang-ABCA-4  Zhuang-ABCA-4          wt/wt         M
# 162574        Zhuang-ABCA-4  Zhuang-ABCA-4          wt/wt         M
# 162575        Zhuang-ABCA-4  Zhuang-ABCA-4          wt/wt         M
# 162576        Zhuang-ABCA-4  Zhuang-ABCA-4          wt/wt         M
# 162577        Zhuang-ABCA-4  Zhuang-ABCA-4          wt/wt         M
#
#         cluster_alias          x         y         z  \
# 0                5249  12.845605  3.428535  1.958952
# 1                4167  12.854068  3.466185  1.958952
# 2                5252  12.828245  3.409277  1.958952
# 3                5252  12.827268  3.403092  1.958952
# 4                5249  12.828462  3.410416  1.958952
# ...               ...        ...       ...       ...
# 162573           5283   3.631468  4.047762  1.780537
# 162574           5283   3.626968  3.951028  1.780537
# 162575           5254   3.642379  3.875565  1.780537
# 162576           5255   3.646696  3.882508  1.780537
# 162577           5263   3.648708  3.838878  1.780537
#
#         subclass_confidence_score  cluster_confidence_score  \
# 0                        0.998365                  0.806205
# 1                        0.928926                  0.928926
# 2                        0.963517                  0.948538
# 3                        0.999984                  0.853408
# 4                        0.999948                  0.999948
# ...                           ...                       ...
# 162573                   0.999987                  0.999987
# 162574                   0.805506                  0.805506
# 162575                   0.997058                  0.825222
# 162576                   0.994641                  0.649077
# 162577                   0.955862                  0.722843
#
#         high_quality_transfer                         abc_sample_id
# 0                        True  5d53075c-ca36-40d5-a718-31e519b2abfb
# 1                        True  88ba4908-07d8-48a2-a85e-d0c10392c2ec
# 2                        True  4d018b6c-0b56-4c2c-b8fe-b591ac155118
# 3                        True  ac646972-132e-4773-9d14-42b426481b8a
# 4                        True  2af329e8-0cab-4622-b41c-187dd764428a
# ...                       ...                                   ...
# 162573                   True  f83412ae-d96d-4a54-b0d4-a8a029a0dc0c
# 162574                   True  fac320b0-ab43-4bc2-9fdc-8f1c61c30a04
# 162575                   True  a265fb34-17f8-4c75-91af-2472d646ebb3
# 162576                   True  92310586-e416-4307-bc90-3c94faac1d3a
# 162577                   True  99017f18-d3c5-4fa1-9872-1b411950a0d9
#
# [162578 rows x 14 columns]

# %%
import pandas as pd

ccf_4 = pd.read_csv('data/zhuang-abca-4/ccf_coordinates.csv')
ccf_4
# Out:
#                                      cell_label          x         y  \
# 0       177536119734259275144748435471942472531  12.392545  3.367893
# 1       256532006537596385088807329967308781746  12.385892  3.406324
# 2        28801318882950773770397006451868070066  12.378531  3.350464
# 3       301971869963235435117242882149875853185  12.380202  3.343970
# 4        81203938259029510162263594992098070595  12.378271  3.351650
# ...                                         ...        ...       ...
# 162356  207078638049612663505414491993744973724   3.953585  3.811305
# 162357  269688622729976403473132483008812650057   3.955631  3.692865
# 162358   32317399564312907213846667957826182632   3.974033  3.600854
# 162359   54832320688289368628112079037767349797   3.977813  3.609686
# 162360  329803029697740405562675653447986491968   3.981242  3.555851
#
#                z  parcellation_index
# 0       1.954545                   0
# 1       1.954782                   0
# 2       1.956634                   0
# 3       1.956501                   0
# 4       1.956652                   0
# ...          ...                 ...
# 162356  1.759242                   0
# 162357  1.763011                   0
# 162358  1.765965                   0
# 162359  1.765565                   0
# 162360  1.767469                 868
#
# [162361 rows x 5 columns]

# %%
# how many slices does zhuang-abca-4 contain? How many cells per sample?
# `abc_sample_id`: an individual sample (animal / batch / experiment)
# `brain_section_label`: a brain slice of one sample

print('How many slices does `zhuang-abca-4` contain? How many cells per slice?\n')
print(
    cells_abca_4["brain_section_label"].value_counts().describe(percentiles=[.01, .05, .1, .25, .5, .75, .9, .95, .99]))
# Out:
# How many slices does `zhuang-abca-4` contain? How many cells per slice?
#
# count        3.000000
# mean     54192.666667
# std      24003.731384
# min      32528.000000
# 1%       32878.500000
# 5%       34280.500000
# 10%      36033.000000
# 25%      41290.500000
# 50%      50053.000000
# 75%      65025.000000
# 90%      74008.200000
# 95%      77002.600000
# 99%      79398.120000
# max      79997.000000
# Name: count, dtype: float64

# %%
# how many brain sections does zhuang-abca-4 contain?


print('How many brain sections does `zhuang-abca-4` contain? How many cells per brain section?\n')
print(ccf_4["parcellation_index"].value_counts().describe(percentiles=[.01, .05, .1, .25, .5, .75, .9, .95, .99]))
# Out:
# How many brain sections does `zhuang-abca-4` contain? How many cells per brain section?
#
# count      219.000000
# mean       741.374429
# std       1695.644941
# min          1.000000
# 1%           1.000000
# 5%           5.000000
# 10%         24.400000
# 25%         86.500000
# 50%        259.000000
# 75%        679.000000
# 90%       1394.400000
# 95%       2287.300000
# 99%       9062.560000
# max      13646.000000
# Name: count, dtype: float64

# %%
# given a brain section, how many samples include the section and how many cells are in this section per sample?
import pandas as pd

ccf_cell_4 = pd.merge(cells_abca_4, ccf_4, how='left', on='cell_label')
ccf_cell_4.groupby('parcellation_index')

print('Given a brain section, how many slices include the section?\n')
print(ccf_cell_4.groupby('parcellation_index')['brain_section_label'].nunique().describe(
    percentiles=[.01, .05, .1, .25, .5, .75, .9, .95, .99]))
# Out:
# Given a brain section, how many slices include the section?
#
# count    219.000000
# mean       1.666667
# std        0.743987
# min        1.000000
# 1%         1.000000
# 5%         1.000000
# 10%        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# 90%        3.000000
# 95%        3.000000
# 99%        3.000000
# max        3.000000
# Name: brain_section_label, dtype: float64

# %%
from NicheQueryPrototype.database import Database

parcellation_tree = Database().parse_parcellation_structure(json_path='data/parcellation/structure.json')
ccf_cell_4['parcellation_level'] = ccf_cell_4['parcellation_index'].map(
    lambda k: parcellation_tree.get(k, {}).get("st_level", -1))

s = (ccf_cell_4
     .groupby(["parcellation_level", "parcellation_index"])["brain_section_label"]
     .nunique())

print('Given a brain section, how many slices include the section group by brain section level?\n')
print(s.groupby(level=0).describe(percentiles=[.01, .05, .1, .25, .5, .75, .9, .95, .99]))
# Out:
# Given a brain section, how many slices include the section group by brain section level?
#
#                     count      mean       std  min    1%    5%  10%   25%  \
# parcellation_level
# -1                   35.0  1.514286  0.658493  1.0  1.00  1.00  1.0  1.00
#  0                    1.0  1.000000       NaN  1.0  1.00  1.00  1.0  1.00
#  1                    2.0  1.500000  0.707107  1.0  1.01  1.05  1.1  1.25
#  2                    2.0  1.000000  0.000000  1.0  1.00  1.00  1.0  1.00
#  3                    1.0  3.000000       NaN  3.0  3.00  3.00  3.0  3.00
#  5                    2.0  1.000000  0.000000  1.0  1.00  1.00  1.0  1.00
#  6                    7.0  1.714286  0.951190  1.0  1.00  1.00  1.0  1.00
#  7                    3.0  1.666667  0.577350  1.0  1.02  1.10  1.2  1.50
#  8                   58.0  1.758621  0.801541  1.0  1.00  1.00  1.0  1.00
#  9                   39.0  1.846154  0.744752  1.0  1.00  1.00  1.0  1.00
#  10                  10.0  1.800000  0.788811  1.0  1.00  1.00  1.0  1.00
#  11                  59.0  1.559322  0.701505  1.0  1.00  1.00  1.0  1.00
#
#                     50%   75%  90%   95%   99%  max
# parcellation_level
# -1                  1.0  2.00  2.0  3.00  3.00  3.0
#  0                  1.0  1.00  1.0  1.00  1.00  1.0
#  1                  1.5  1.75  1.9  1.95  1.99  2.0
#  2                  1.0  1.00  1.0  1.00  1.00  1.0
#  3                  3.0  3.00  3.0  3.00  3.00  3.0
#  5                  1.0  1.00  1.0  1.00  1.00  1.0
#  6                  1.0  2.50  3.0  3.00  3.00  3.0
#  7                  2.0  2.00  2.0  2.00  2.00  2.0
#  8                  2.0  2.00  3.0  3.00  3.00  3.0
#  9                  2.0  2.00  3.0  3.00  3.00  3.0
#  10                 2.0  2.00  3.0  3.00  3.00  3.0
#  11                 1.0  2.00  3.0  3.00  3.00  3.0

# %%
s = (ccf_cell_4
     .groupby(["parcellation_level"])["parcellation_index"]
     .nunique())

print('# parcellations group by levels\n')
print(s)
# Out:
# # parcellations group by levels
#
# parcellation_level
# -1     35
#  0      1
#  1      2
#  2      2
#  3      1
#  5      2
#  6      7
#  7      3
#  8     58
#  9     39
#  10    10
#  11    59
# Name: parcellation_index, dtype: int64

# %%
s = (ccf_cell_4
     .groupby(["parcellation_level", "parcellation_index"])["cell_label"]
     .nunique())

print('Given a brain section, how many cells in the brain section per brian slice group by brain section level?\n')
print(s.groupby(level=0).describe(percentiles=[.01, .05, .1, .25, .5, .75, .9, .95, .99]))
# Out:
# Given a brain section, how many cells in the brain section per brian slice group by brain section level?
#
#                     count         mean          std     min       1%       5%  \
# parcellation_level
# -1                   35.0   342.628571   600.505673     1.0     1.00    10.10
#  0                    1.0  8154.000000          NaN  8154.0  8154.00  8154.00
#  1                    2.0   498.500000   526.794552   126.0   133.45   163.25
#  2                    2.0   193.000000   270.114790     2.0     5.82    21.10
#  3                    1.0   284.000000          NaN   284.0   284.00   284.00
#  5                    2.0    82.000000    55.154329    43.0    43.78    46.90
#  6                    7.0   585.285714   442.911471    33.0    52.44   130.20
#  7                    3.0  2349.333333  3446.338975   111.0   121.16   161.80
#  8                   58.0   663.982759  1008.852196     1.0     1.00     4.55
#  9                   39.0   705.794872  1250.864421     3.0    14.02    32.00
#  10                  10.0   308.000000   271.325962    42.0    42.18    42.90
#  11                  59.0  1019.016949  2606.546734     1.0     1.58     4.80
#
#                        10%      25%     50%      75%     90%      95%  \
# parcellation_level
# -1                    24.6    67.00   130.0   363.00   772.2   870.10
#  0                  8154.0  8154.00  8154.0  8154.00  8154.0  8154.00
#  1                   200.5   312.25   498.5   684.75   796.5   833.75
#  2                    40.2    97.50   193.0   288.50   345.8   364.90
#  3                   284.0   284.00   284.0   284.00   284.0   284.00
#  5                    50.8    62.50    82.0   101.50   113.2   117.10
#  6                   227.4   374.50   507.0   676.00  1006.0  1231.00
#  7                   212.6   365.00   619.0  3468.50  5178.2  5748.10
#  8                    20.2   111.50   411.0   741.50  1442.2  2218.85
#  9                    58.0   136.00   307.0   608.00  1824.4  2099.20
#  10                   43.8    95.75   267.5   365.75   607.9   760.45
#  11                   17.4    45.50   233.0   692.50  1418.0  4830.40
#
#                          99%      max
# parcellation_level
# -1                   2574.64   3443.0
#  0                   8154.00   8154.0
#  1                    863.55    871.0
#  2                    380.18    384.0
#  3                    284.00    284.0
#  5                    120.22    121.0
#  6                   1411.00   1456.0
#  7                   6204.02   6318.0
#  8                   4719.07   6286.0
#  9                   5416.98   7328.0
#  10                   882.49    913.0
#  11                 12726.12  13646.0

# %% [markdown]
# ## Choose a parcellation for spot check

# %%
ccf_cell_4
# Out:
#                                      cell_label brain_section_label  \
# 0       177536119734259275144748435471942472531   Zhuang-ABCA-4.002
# 1       256532006537596385088807329967308781746   Zhuang-ABCA-4.002
# 2        28801318882950773770397006451868070066   Zhuang-ABCA-4.002
# 3       301971869963235435117242882149875853185   Zhuang-ABCA-4.002
# 4        81203938259029510162263594992098070595   Zhuang-ABCA-4.002
# ...                                         ...                 ...
# 162573  207078638049612663505414491993744973724   Zhuang-ABCA-4.001
# 162574  269688622729976403473132483008812650057   Zhuang-ABCA-4.001
# 162575   32317399564312907213846667957826182632   Zhuang-ABCA-4.001
# 162576   54832320688289368628112079037767349797   Zhuang-ABCA-4.001
# 162577  329803029697740405562675653447986491968   Zhuang-ABCA-4.001
#
#        feature_matrix_label    donor_label donor_genotype donor_sex  \
# 0             Zhuang-ABCA-4  Zhuang-ABCA-4          wt/wt         M
# 1             Zhuang-ABCA-4  Zhuang-ABCA-4          wt/wt         M
# 2             Zhuang-ABCA-4  Zhuang-ABCA-4          wt/wt         M
# 3             Zhuang-ABCA-4  Zhuang-ABCA-4          wt/wt         M
# 4             Zhuang-ABCA-4  Zhuang-ABCA-4          wt/wt         M
# ...                     ...            ...            ...       ...
# 162573        Zhuang-ABCA-4  Zhuang-ABCA-4          wt/wt         M
# 162574        Zhuang-ABCA-4  Zhuang-ABCA-4          wt/wt         M
# 162575        Zhuang-ABCA-4  Zhuang-ABCA-4          wt/wt         M
# 162576        Zhuang-ABCA-4  Zhuang-ABCA-4          wt/wt         M
# 162577        Zhuang-ABCA-4  Zhuang-ABCA-4          wt/wt         M
#
#         cluster_alias        x_x       y_x       z_x  \
# 0                5249  12.845605  3.428535  1.958952
# 1                4167  12.854068  3.466185  1.958952
# 2                5252  12.828245  3.409277  1.958952
# 3                5252  12.827268  3.403092  1.958952
# 4                5249  12.828462  3.410416  1.958952
# ...               ...        ...       ...       ...
# 162573           5283   3.631468  4.047762  1.780537
# 162574           5283   3.626968  3.951028  1.780537
# 162575           5254   3.642379  3.875565  1.780537
# 162576           5255   3.646696  3.882508  1.780537
# 162577           5263   3.648708  3.838878  1.780537
#
#         subclass_confidence_score  cluster_confidence_score  \
# 0                        0.998365                  0.806205
# 1                        0.928926                  0.928926
# 2                        0.963517                  0.948538
# 3                        0.999984                  0.853408
# 4                        0.999948                  0.999948
# ...                           ...                       ...
# 162573                   0.999987                  0.999987
# 162574                   0.805506                  0.805506
# 162575                   0.997058                  0.825222
# 162576                   0.994641                  0.649077
# 162577                   0.955862                  0.722843
#
#         high_quality_transfer                         abc_sample_id  \
# 0                        True  5d53075c-ca36-40d5-a718-31e519b2abfb
# 1                        True  88ba4908-07d8-48a2-a85e-d0c10392c2ec
# 2                        True  4d018b6c-0b56-4c2c-b8fe-b591ac155118
# 3                        True  ac646972-132e-4773-9d14-42b426481b8a
# 4                        True  2af329e8-0cab-4622-b41c-187dd764428a
# ...                       ...                                   ...
# 162573                   True  f83412ae-d96d-4a54-b0d4-a8a029a0dc0c
# 162574                   True  fac320b0-ab43-4bc2-9fdc-8f1c61c30a04
# 162575                   True  a265fb34-17f8-4c75-91af-2472d646ebb3
# 162576                   True  92310586-e416-4307-bc90-3c94faac1d3a
# 162577                   True  99017f18-d3c5-4fa1-9872-1b411950a0d9
#
#               x_y       y_y       z_y  parcellation_index  parcellation_level
# 0       12.392545  3.367893  1.954545                 0.0                  -1
# 1       12.385892  3.406324  1.954782                 0.0                  -1
# 2       12.378531  3.350464  1.956634                 0.0                  -1
# 3       12.380202  3.343970  1.956501                 0.0                  -1
# 4       12.378271  3.351650  1.956652                 0.0                  -1
# ...           ...       ...       ...                 ...                 ...
# 162573   3.953585  3.811305  1.759242                 0.0                  -1
# 162574   3.955631  3.692865  1.763011                 0.0                  -1
# 162575   3.974033  3.600854  1.765965                 0.0                  -1
# 162576   3.977813  3.609686  1.765565                 0.0                  -1
# 162577   3.981242  3.555851  1.767469               868.0                  10
#
# [162578 rows x 19 columns]

# %%
ccf_cell_4.donor_label.nunique()
# Out:
# 1

# %%
# random select a parcellation & sample

# step 1: print parcellation at a specific level # 987
target_parcellations = ccf_cell_4[ccf_cell_4['parcellation_level'] == 6]['parcellation_index'].unique()
print(f"Check parcellation at level 6: {target_parcellations}")
# Out:
# Check parcellation at level 6: [ 485.  987.  467. 1080. 1073.  645.  541.]

# %%
# random select a parcellation & sample

# step 1: print parcellation at a specific level
target_parcellations = ccf_cell_4[ccf_cell_4['parcellation_level'] == 5]['parcellation_index'].unique()
print(f"Check parcellation at level 5: {target_parcellations}")
# Out:
# Check parcellation at level 5: [ 549. 1097.]

# %%
# step 2: check # samples with this parcellation
target_parcellation = 207

with pd.option_context("display.max_rows", None,
                       "display.max_columns", None,
                       "display.width", None,
                       "display.max_colwidth", None):
    s = ccf_cell_4[ccf_cell_4['parcellation_index'] == target_parcellation]['brain_section_label'].value_counts()
    print(
        f"Samples with this parcellation & # cells in this parcellation per sample: \n{s}")
    print(f"Total samples: {s.shape[0]} out of {ccf_cell_4['brain_section_label'].nunique()}")
# Out:
# Samples with this parcellation & # cells in this parcellation per sample:
# Series([], Name: count, dtype: int64)
# Total samples: 0 out of 3

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import BoundaryNorm, ListedColormap


def visualize_parcellation_subtree_on_section(
    df,
    parcellation_tree,
    brain_section_label,
    parcellation_index,
    *,
    x_col="x_x",
    y_col="y_x",
    section_col="brain_section_label",
    parc_col="parcellation_index",
    figsize=(9, 9),
    show=True,
):
    """Plot one brain section using cell_metadata x/y (default ``x_x`` / ``y_x`` after merge).

    Cells outside the target subtree are light gray. Descendant ``parcellation_index`` values are
    colored by **category** (IDs are arbitrary, not a continuous scale).

    Returns ``(fig, ax)``.
    """

    def _cell_in_subtree(pid, root_id, tree):
        if pd.isna(pid):
            return False
        info = tree.get(int(pid), {})
        return root_id in (info.get("parent_ids") or set())

    root_id = int(parcellation_index)
    sec = df[df[section_col] == brain_section_label]
    if sec.empty:
        raise ValueError(f"No cells for brain_section_label={brain_section_label!r}")

    sub_mask = sec[parc_col].map(lambda p: _cell_in_subtree(p, root_id, parcellation_tree))
    hl = sec.loc[sub_mask].copy()

    region_name = parcellation_tree.get(root_id, {}).get("name", "?")
    fig, ax = plt.subplots(figsize=figsize)

    other = sec.loc[~sub_mask]
    if not other.empty:
        ax.scatter(
            other[x_col],
            other[y_col],
            s=0.45,
            c="#a8a8a8",
            alpha=0.75,
            linewidths=0,
            rasterized=True,
            label="outside target subtree",
        )

    if hl.empty:
        ax.set_title(f"{brain_section_label}\nNo cells under CCF id {root_id} ({region_name})")
        if not other.empty:
            ax.legend(loc="upper right", framealpha=0.9)
    else:
        hl["pid"] = hl[parc_col].astype(int)
        uniq = np.sort(hl["pid"].unique())
        n = len(uniq)
        pid_to_code = {p: i for i, p in enumerate(uniq)}
        codes = hl["pid"].map(pid_to_code).to_numpy(dtype=float)

        tab20 = plt.cm.tab20(np.linspace(0, 1, 20, endpoint=False))
        tab20b = plt.cm.tab20b(np.linspace(0, 1, 20, endpoint=False))
        set3 = plt.cm.Set3(np.linspace(0, 1, 12, endpoint=False))
        pal = np.vstack([tab20, tab20b, set3])
        colors = [pal[i % len(pal)] for i in range(n)]
        cmap = ListedColormap(colors)
        bounds = np.arange(n + 1) - 0.5
        norm = BoundaryNorm(bounds, cmap.N)

        sc = ax.scatter(
            hl[x_col],
            hl[y_col],
            c=codes,
            cmap=cmap,
            norm=norm,
            s=1.2,
            alpha=0.9,
            linewidths=0,
        )
        cbar = plt.colorbar(sc, ax=ax, fraction=0.035, pad=0.02, ticks=np.arange(n))
        cbar.ax.set_yticklabels([str(u) for u in uniq])
        cbar.set_label("parcellation_index (categorical)")

        if not other.empty:
            ax.legend(loc="upper right", framealpha=0.9)

        ax.set_title(
            f"{brain_section_label}\nCCF {root_id} — {region_name}\n"
            f"{len(hl):,} cells in this structure or its descendants"
        )

    ax.set_xlabel("x (cell_metadata)")
    ax.set_ylabel("y (cell_metadata)")
    ax.set_aspect("equal", adjustable="box")
    fig.tight_layout()
    if show:
        plt.show()
    return fig, ax


target_sample_ids = ['zhuang-abca-4.098', 'zhuang-abca-4.099', 'zhuang-abca-4.097', 'zhuang-abca-4.096',
                     'zhuang-abca-4.100', 'zhuang-abca-4.101', 'zhuang-abca-4.102', 'zhuang-abca-4.095',
                     'zhuang-abca-4.103', 'zhuang-abca-4.104']
for sample_id in target_sample_ids:
    visualize_parcellation_subtree_on_section(
        ccf_cell_4,
        parcellation_tree,
        brain_section_label=sample_id,
        parcellation_index=target_parcellation,
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 116
#     108 target_sample_ids = ['Zhuang-ABCA-1.098', 'Zhuang-ABCA-1.099', 'Zhuang-ABCA-1.097', 'Zhuang-ABCA-1.096',
#     109                      'Zhuang-ABCA-1.100', 'Zhuang-ABCA-1.101', 'Zhuang-ABCA-1.102', 'Zhuang-ABCA-1.095',
#     110                      'Zhuang-ABCA-1.103', 'Zhuang-ABCA-1.104']
#     111 for sample_id in target_sample_ids:
#     112     visualize_parcellation_subtree_on_section(
#     113         ccf_cell_4,
#     114         parcellation_tree,
#     115         brain_section_label=sample_id,
# --> 116         parcellation_index=target_parcellation,
#     117     )
#
# NameError: name 'target_parcellation' is not defined
